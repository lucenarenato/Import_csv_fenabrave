# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardo99i/Fenabrave/blob/main/TESTE_WEB_SCRAPING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importação das lib's utilizadas
import pandas as pd
from urllib.request import urlopen
import html
from bs4 import BeautifulSoup
import csv

html = urlopen("http://www.fenabrave.org.br/pdf/informativo/automatico/dadosregionais_novo.asp?id=Sao%20Paulo&cap=")
soup = BeautifulSoup(html.read(), "html5lib")
extrai_tabela = soup.findAll("table", {"class": "TABELA"})
for tag in extrai_tabela:
        table_str = str(extrai_tabela)
        tabela_pronta = pd.read_html(table_str)[0]
        display(tabela_pronta)
# Out:
#                           0                         1        2        3   \
# 0                  Segmentos                 Segmentos     2022     2022
# 1                  Segmentos                 Segmentos  Jul (A)  Jun (B)
# 2                    (A)Auto                   (A)Auto    37603    36834
# 3          (B)Comercial Leve         (B)Comercial Leve     5422     5222
# 4                      (A+B)                     (A+B)    43025    42056
# 5                (C)Caminhão               (C)Caminhão     2213     2333
# 6                  (D)Ônibus                 (D)Ônibus      333      515
# 7                      (C+D)                     (C+D)     2546     2848
# 8                    (E)Moto                   (E)Moto    23305    26731
# 9   (F)Implemento Rodoviário  (F)Implemento Rodoviário     1727     1743
# 10                    Outros                    Outros     2108     1937
# 11                     TOTAL                     TOTAL    72711    75315
#
# ...

# %%
tabela_pronta.to_csv('UF_SP.csv')
